# %% [markdown]
# ## Captura de la pose a través de la webcam con MediaPipe

# %%
import cv2
import mediapipe as mp
import numpy as np
import time
import socket
import json

def calculate_angle(a, b, c):
    """Calculates the angle at point b given points a and c."""
    a = np.array((a.x, a.y))
    b = np.array((b.x, b.y))
    c = np.array((c.x, c.y))

    radians = np.arctan2(c[1]-b[1], c[0]-b[0]) - np.arctan2(a[1]-b[1], a[0]-b[0])
    angle = np.abs(radians * 180.0 / np.pi)
    
    if angle > 180.0:
        angle = 360 - angle
    return angle

def arm_raised(shoulder, elbow, wrist, hip):
    arm_straightness = calculate_angle(shoulder, elbow, wrist)
    
    x_diff_se = abs(shoulder.x - elbow.x)
    x_diff_ew = abs(elbow.x - wrist.x)
    is_aligned_x = x_diff_se < 0.05 and x_diff_ew < 0.05

    is_up = wrist.y < shoulder.y

    return arm_straightness > 160 and is_aligned_x and is_up

def arm_horizontal(shoulder, elbow, wrist):
    arm_straightness = calculate_angle(shoulder, elbow, wrist)

    y_diff_se = abs(shoulder.y - elbow.y)
    y_diff_ew = abs(elbow.y - wrist.y)
    is_level = y_diff_se < 0.05 and y_diff_ew < 0.05
    return arm_straightness > 160 and is_level

def crouched(hip, knee, ankle):
    leg_bend = calculate_angle(hip, knee, ankle)
    vertical_dist = abs(hip.y - ankle.y)
    return leg_bend < 100 or vertical_dist < 0.3

def detect_jump(right_hip, left_hip, prev_y, arms_raised):
    current_y = (right_hip.y + left_hip.y) / 2

    jump_detected = False
    if prev_y is not None:
        velocity = prev_y - current_y
        if velocity > 0.05 and arms_raised:
            jump_detected = True
    return jump_detected, current_y

# Conexión con Godot
sock = socket.socket(socket.AF_INET, socket.SOCK_DGRAM)

# Inicializar MediaPipe
mp_pose = mp.solutions.pose
pose = mp_pose.Pose(
    min_detection_confidence=0.7,
    min_tracking_confidence=0.7
)
mp_drawing = mp.solutions.drawing_utils

prev_hip_y = None
is_jumping = False
jump_start_time = 0

last_gesture = None

# Usar la cámara (0 = cámara principal)
cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # MediaPipe requiere RGB
    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    # Procesar pose
    results = pose.process(frame_rgb)

    # Dibujar landmarks si existen
    if results.pose_landmarks:

        mp_drawing.draw_landmarks(
            frame,
            results.pose_landmarks,
            mp_pose.POSE_CONNECTIONS,
            mp_drawing.DrawingSpec(color=(255, 0, 0), thickness=4, circle_radius=2),
            mp_drawing.DrawingSpec(color=(255, 0, 0), thickness=6, circle_radius=2)
        )

        landmarks = results.pose_landmarks.landmark

        right_shoulder = landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER]
        left_shoulder = landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER]

        right_elbow = landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW]
        left_elbow = landmarks[mp_pose.PoseLandmark.LEFT_ELBOW]
        right_wrist = landmarks[mp_pose.PoseLandmark.RIGHT_WRIST]
        left_wrist = landmarks[mp_pose.PoseLandmark.LEFT_WRIST]

        right_hip = landmarks[mp_pose.PoseLandmark.RIGHT_HIP]
        left_hip = landmarks[mp_pose.PoseLandmark.LEFT_HIP]
        right_knee = landmarks[mp_pose.PoseLandmark.RIGHT_KNEE]
        left_knee = landmarks[mp_pose.PoseLandmark.LEFT_KNEE]

        right_ankle = landmarks[mp_pose.PoseLandmark.RIGHT_ANKLE]
        left_ankle = landmarks[mp_pose.PoseLandmark.LEFT_ANKLE]

        cv2.putText(frame, "RIGHT", (int(right_wrist.x * frame.shape[1]), int(right_wrist.y * frame.shape[0])), 
                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
        
        cv2.putText(frame, "LEFT", (int(left_wrist.x * frame.shape[1]), int(left_wrist.y * frame.shape[0])), 
                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

        threshold = 0.05

        gesture = "NO GESTURE"
        color = (0, 0, 255)
        arms_raised = False
        data = {
            "move_right": 0,
            "move_left": 0,
            "jump": 0,
            "crouch": 0,
            "shoot": 0
        }

        if crouched(right_hip, right_knee, right_ankle) or crouched(left_hip, left_knee, left_ankle):
            gesture = "CROUCHED" 
            color = (255, 0, 0)
            data["crouch"] = 1
        elif arm_raised(right_shoulder, right_elbow, right_wrist, right_hip) and arm_raised(left_shoulder, left_elbow, left_wrist, left_hip):
            gesture = "BOTH ARMS RAISED VERTICAL"
            color = (0, 255, 0)
            arms_raised = True
            data["jump"] = 1
        elif arm_raised(right_shoulder, right_elbow, right_wrist, right_hip):
            gesture = "RIGHT ARM RAISED VERTICAL"
            color = (0, 255, 0)
            # Pendiente de asignar acción
        elif arm_horizontal(right_shoulder, right_elbow, right_wrist):
            gesture = "RIGHT ARM HORIZONTAL"
            color = (0, 255, 255)
            data["move_right"] = 1
        elif arm_raised(left_shoulder, left_elbow, left_wrist, left_hip):
            gesture = "LEFT ARM RAISED VERTICAL"
            color = (0, 255, 0)
            data["shoot"] = 1
        elif arm_horizontal(left_shoulder, left_elbow, left_wrist):
            gesture = "LEFT ARM HORIZONTAL"
            color = (0, 255, 255)
            data["move_left"] = 1
        

        jump_now, prev_hip_y = detect_jump(right_hip, left_hip, prev_hip_y, arms_raised)
        
        if jump_now:
            is_jumping = True
            jump_start_time = time.time()

        if is_jumping:
            gesture = "JUMPING"
            color = (0, 165, 255)
            if time.time() - jump_start_time > 0.8: # Show for 500ms
                is_jumping = False

        cv2.putText(frame, gesture, (30, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, color, 2, cv2.LINE_AA)

        if gesture != "NO GESTURE" and gesture != last_gesture:
            payload = json.dumps(data).encode('utf-8')
            sock.sendto(payload, ("127.0.0.1", 6005))
            last_gesture = gesture
            print("Mensaje enviado.")

    # Mostrar
    cv2.imshow("Webcam - Pose", frame)
    # Salir con 'ESC'
    key = cv2.waitKey(1) & 0xFF
    if key == 27:
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Mensaje enviado.
# Mensaje enviado.
# Mensaje enviado.
# Mensaje enviado.
# Mensaje enviado.
# Mensaje enviado.
# Mensaje enviado.
# Mensaje enviado.

# %% [markdown]
# ## Conexión con Godot a través de puertos

# %% [markdown]
# Código de prueba

# %%
import socket
import json
import keyboard

sock = socket.socket(socket.AF_INET, socket.SOCK_DGRAM)
data = {
    "move_x": [],
    "jump": 0,
    "shoot": 0
}

# Serializar
payload = json.dumps(data).encode('utf-8')
sock.sendto(payload, ("127.0.0.1", 6005))

print("Enviado.")
# Out:
# Enviado.
